# %% [markdown]
# # Setup

# %%
# !pip3 uninstall datasets -y
# !pip3 install bitsandbytes transformers accelerate peft Pillow torch torchvision torchaudio tensorflow tensorrt ipywidgets -q
# !pip3 install --upgrade notebook jupyter -q
# !pip3 install huggingface-hub==0.23.1
# Out:
# Found existing installation: datasets 2.19.2.dev0
# Uninstalling datasets-2.19.2.dev0:
#   Successfully uninstalled datasets-2.19.2.dev0
# Requirement already satisfied: huggingface-hub==0.23.1 in ./moody-env/lib/python3.10/site-packages (0.23.1)
# Requirement already satisfied: filelock in ./moody-env/lib/python3.10/site-packages (from huggingface-hub==0.23.1) (3.14.0)
# Requirement already satisfied: packaging>=20.9 in ./moody-env/lib/python3.10/site-packages (from huggingface-hub==0.23.1) (24.0)
# Requirement already satisfied: tqdm>=4.42.1 in ./moody-env/lib/python3.10/site-packages (from huggingface-hub==0.23.1) (4.66.4)
# Requirement already satisfied: requests in ./moody-env/lib/python3.10/site-packages (from huggingface-hub==0.23.1) (2.32.2)
# Requirement already satisfied: fsspec>=2023.5.0 in ./moody-env/lib/python3.10/site-packages (from huggingface-hub==0.23.1) (2024.3.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in ./moody-env/lib/python3.10/site-packages (from huggingface-hub==0.23.1) (4.12.0)
# Requirement already satisfied: pyyaml>=5.1 in ./moody-env/lib/python3.10/site-packages (from huggingface-hub==0.23.1) (6.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./moody-env/lib/python3.10/site-packages (from requests->huggingface-hub==0.23.1) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./moody-env/lib/python3.10/site-packages (from requests->huggingface-hub==0.23.1) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in ./moody-env/lib/python3.10/site-packages (from requests->huggingface-hub==0.23.1) (2024.2.2)
# Requirement already satisfied: idna<4,>=2.5 in ./moody-env/lib/python3.10/site-packages (from requests->huggingface-hub==0.23.1) (3.7)

# %%
# !pip3 install git+https://github.com/huggingface/diffusers.git -q

# %%
# !pip3 install datasets
# Out:
# Collecting datasets
#   Using cached datasets-2.19.1-py3-none-any.whl (542 kB)
# Requirement already satisfied: multiprocess in ./moody-env/lib/python3.10/site-packages (from datasets) (0.70.16)
# Requirement already satisfied: filelock in ./moody-env/lib/python3.10/site-packages (from datasets) (3.14.0)
# Requirement already satisfied: fsspec[http]<=2024.3.1,>=2023.1.0 in ./moody-env/lib/python3.10/site-packages (from datasets) (2024.3.1)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in ./moody-env/lib/python3.10/site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in ./moody-env/lib/python3.10/site-packages (from datasets) (2.2.2)
# Requirement already satisfied: packaging in ./moody-env/lib/python3.10/site-packages (from datasets) (24.0)
# Requirement already satisfied: requests>=2.19.0 in ./moody-env/lib/python3.10/site-packages (from datasets) (2.32.2)
# Requirement already satisfied: pyarrow>=12.0.0 in ./moody-env/lib/python3.10/site-packages (from datasets) (16.1.0)
# Requirement already satisfied: tqdm>=4.62.1 in ./moody-env/lib/python3.10/site-packages (from datasets) (4.66.4)
# Requirement already satisfied: pyarrow-hotfix in ./moody-env/lib/python3.10/site-packages (from datasets) (0.6)
# Requirement already satisfied: xxhash in ./moody-env/lib/python3.10/site-packages (from datasets) (3.4.1)
# Requirement already satisfied: pyyaml>=5.1 in ./moody-env/lib/python3.10/site-packages (from datasets) (6.0.1)
# Requirement already satisfied: numpy>=1.17 in ./moody-env/lib/python3.10/site-packages (from datasets) (1.26.4)
# Requirement already satisfied: aiohttp in ./moody-env/lib/python3.10/site-packages (from datasets) (3.9.5)
# Requirement already satisfied: huggingface-hub>=0.21.2 in ./moody-env/lib/python3.10/site-packages (from datasets) (0.23.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in ./moody-env/lib/python3.10/site-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: frozenlist>=1.1.1 in ./moody-env/lib/python3.10/site-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in ./moody-env/lib/python3.10/site-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: aiosignal>=1.1.2 in ./moody-env/lib/python3.10/site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./moody-env/lib/python3.10/site-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: attrs>=17.3.0 in ./moody-env/lib/python3.10/site-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in ./moody-env/lib/python3.10/site-packages (from huggingface-hub>=0.21.2->datasets) (4.12.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./moody-env/lib/python3.10/site-packages (from requests>=2.19.0->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in ./moody-env/lib/python3.10/site-packages (from requests>=2.19.0->datasets) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./moody-env/lib/python3.10/site-packages (from requests>=2.19.0->datasets) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in ./moody-env/lib/python3.10/site-packages (from requests>=2.19.0->datasets) (2024.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./moody-env/lib/python3.10/site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in ./moody-env/lib/python3.10/site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: pytz>=2020.1 in ./moody-env/lib/python3.10/site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: six>=1.5 in ./moody-env/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Installing collected packages: datasets
# Successfully installed datasets-2.19.1

# %%
import sys
print(sys.executable)
# Out:
# /home/emma/code/emotiscope/moody-env/bin/python3

# %%
import requests
from transformers import AutoProcessor, BlipForConditionalGeneration
import torch

device = "cuda" if torch.cuda.is_available() else "CPU"
print(device)


import tensorflow as tf

# Check if a GPU is available and TensorRT is integrated
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        # Attempt to create a simple TensorRT graph
        tf.config.experimental.set_memory_growth(gpus[0], True)
        from tensorflow.python.compiler.tensorrt import trt_convert as trt
        print("TensorRT is available!")
    except ImportError as e:
        print("TensorRT integration not available:", e)
else:
    print("GPU not available.")
# Out:
# cuda
# TensorRT is available!

# %%
# !nvidia-smi
# Out:
# Tue May 28 20:08:59 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.171.04             Driver Version: 535.171.04   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA GeForce RTX 3090        Off | 00000000:1A:00.0 Off |                  N/A |
# |  0%   21C    P8              15W / 350W |    932MiB / 24576MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
# |   1  NVIDIA GeForce RTX 3090        Off | 00000000:68:00.0 Off |                  N/A |
# |  0%   24C    P8              27W / 350W |    642MiB / 24576MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |    0   N/A  N/A      1447      G   /usr/lib/xorg/Xorg                            4MiB |
# |    0   N/A  N/A      1763      C   /usr/local/bin/ollama                       572MiB |
# |    0   N/A  N/A    175600      C   ...de/emotiscope/moody-env/bin/python3      342MiB |
# |    1   N/A  N/A      1447      G   /usr/lib/xorg/Xorg                           46MiB |
# |    1   N/A  N/A      1556      G   /usr/bin/gnome-shell                         10MiB |
# |    1   N/A  N/A      1763      C   /usr/local/bin/ollama                       572MiB |
# +---------------------------------------------------------------------------------------+

# %%
# !wget https://raw.githubusercontent.com/huggingface/diffusers/main/examples/dreambooth/train_dreambooth_lora_sdxl.py
# Out:
# --2024-05-28 20:08:59--  https://raw.githubusercontent.com/huggingface/diffusers/main/examples/dreambooth/train_dreambooth_lora_sdxl.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 84311 (82K) [text/plain]
# Saving to: ‘train_dreambooth_lora_sdxl.py.2’
#
# train_dreambooth_lo 100%[===================>]  82.33K  --.-KB/s    in 0.005s
#
# 2024-05-28 20:08:59 (16.2 MB/s) - ‘train_dreambooth_lora_sdxl.py.2’ saved [84311/84311]

# %%
from huggingface_hub import notebook_login
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
import logging

# Set up basic configuration for logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# %% [markdown]
# # Constants

# %%
MODEL_NAME = "claymore"
INPUT_FOLDER = f"./{MODEL_NAME.replace(' ', '-')}/"
EXTENSIONS = (".png", ".jpg", ".jpeg", ".webp")  # Added support for jpg, jpeg, and webp
INPUT_FILES = [f"{INPUT_FOLDER}*{ext}" for ext in EXTENSIONS] 
CAPTION_PREFIX ="a TOK emoticon"

# %% [markdown]
# # Load Photos

# %%
from PIL import Image

def image_grid(imgs, rows, cols, resize=256):

    if resize is not None:
        imgs = [img.resize((resize, resize)) for img in imgs]
    w, h = imgs[0].size
    grid = Image.new("RGB", size=(cols * w, rows * h))
    grid_w, grid_h = grid.size

    for i, img in enumerate(imgs):
        grid.paste(img, box=(i % cols * w, i // cols * h))
    return grid

# %%
import glob

def load_images(file_patterns):
    imgs = []
    for pattern in file_patterns:
        for file in glob.glob(pattern):  # Process each pattern individually
            try:
                img = Image.open(file)
                imgs.append(img)
            except IOError as e:
                print(f"Failed to load image {file}: {str(e)}")
    return imgs

# Load all images that match the patterns in INPUT_FILES
imgs = load_images(INPUT_FILES)

num_imgs_to_preview = 5
image_grid(imgs[:num_imgs_to_preview], 1, num_imgs_to_preview)
# Out:
# <PIL.Image.Image image mode=RGB size=1280x256>

# %%
# load the processor and the captioning model
blip_processor = AutoProcessor.from_pretrained("Salesforce/blip-image-captioning-base")
blip_model = BlipForConditionalGeneration.from_pretrained("Salesforce/blip-image-captioning-base",torch_dtype=torch.float16).to(device)

# captioning utility
def caption_images(input_image):
    inputs = blip_processor(images=input_image, return_tensors="pt").to(device, torch.float16)
    pixel_values = inputs.pixel_values

    generated_ids = blip_model.generate(pixel_values=pixel_values, max_length=50)
    generated_caption = blip_processor.batch_decode(generated_ids, skip_special_tokens=True)[0]
    return generated_caption

# %%
import glob
from PIL import Image

def load_images_and_paths(file_patterns):
    imgs_and_paths = []
    for pattern in file_patterns:
        for path in glob.glob(pattern):
            try:
                img = Image.open(path)
                imgs_and_paths.append((path, img))
            except IOError as e:
                print(f"Failed to open image {path}: {str(e)}")
    return imgs_and_paths

# Load images and their paths using the correct file patterns
imgs_and_paths = load_images_and_paths(INPUT_FILES)

# %%
import json
from multiprocessing import Pool

def process_image(img_and_path):
    img, path = img_and_path
    logging.info(f"Processing image: {img}")
    
    try:
        caption = CAPTION_PREFIX + caption_images(path).split("\n")[0]
        result = {
            "file_name": img.split("/")[-1],  # Assumes `img` is a path
            "prompt": caption
        }
        logging.info(f"Finished processing image: {img}")
        return result
    except Exception as e:
        logging.error(f"Error processing image {img}: {str(e)}")
        return None


logging.info("Starting the multiprocessing task")
    
with open(f'{INPUT_FOLDER}metadata.jsonl', 'w') as outfile:
    for entry in imgs_and_paths:
        if entry is not None:
            result = process_image(entry)
            json.dump(result, outfile)
            outfile.write('\n')

logging.info("Completed the multiprocessing task")
# Out:
# 2024-05-28 21:17:46,321 - INFO - Starting the multiprocessing task
# 2024-05-28 21:17:46,324 - INFO - Processing image: ./claymore/751422ce2010a125046054c08370aadd.png
# 2024-05-28 21:17:51,471 - INFO - Finished processing image: ./claymore/12-13.webp
# 2024-05-28 21:17:51,472 - INFO - Processing image: ./claymore/Octavia_awakened.webp
# 2024-05-28 21:17:51,595 - INFO - Finished processing image: ./claymore/Octavia_awakened.webp
# 2024-05-28 21:17:51,597 - INFO - Completed the multiprocessing task

# %% [markdown]
# # Free Memory

# %%
import gc

# delete the BLIP pipelines and free up some memory
del blip_processor, blip_model
gc.collect()
torch.cuda.empty_cache()

# %% [markdown]
# # Prep for Training

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# !accelerate config default
# Out:
# Configuration already exists at /home/emma/.cache/huggingface/accelerate/default_config.yaml, will not override. Run `accelerate config` manually or pass a different `save_location`.

# %%
# Prepare the command
# command = f"""
# !accelerate launch train_dreambooth_lora_sdxl.py \\
#   --pretrained_model_name_or_path="stabilityai/stable-diffusion-xl-base-1.0" \\
#   --pretrained_vae_model_name_or_path="madebyollin/sdxl-vae-fp16-fix" \\
#   --dataset_name="{MODEL_NAME}" \\
#   --output_dir="{MODEL_NAME}_LoRA" \\
#   --caption_column="prompt" \\
#   --mixed_precision="fp16" \\
#   --instance_prompt="a TOK emoticon" \\
#   --resolution=1024 \\
#   --train_batch_size=1 \\
#   --gradient_accumulation_steps=3 \\
#   --gradient_checkpointing \\
#   --learning_rate=1e-4 \\
#   --snr_gamma=5.0 \\
#   --lr_scheduler="constant" \\
#   --lr_warmup_steps=0 \\
#   --mixed_precision="fp16" \\
#   --use_8bit_adam \\
#   --max_train_steps=500 \\
#   --checkpointing_steps=717 \\
#   --seed="0"
# """

# print(command)


# !accelerate launch train_dreambooth_lora_sdxl.py \
  --pretrained_model_name_or_path="stabilityai/stable-diffusion-xl-base-1.0" \
  --pretrained_vae_model_name_or_path="madebyollin/sdxl-vae-fp16-fix" \
  --dataset_name="claymore" \
  --output_dir="claymore_LoRA" \
  --caption_column="prompt" \
  --mixed_precision="fp16" \
  --instance_prompt="a TOK emoticon" \
  --resolution=1024 \
  --train_batch_size=1 \
  --gradient_accumulation_steps=3 \
  --gradient_checkpointing \
  --learning_rate=1e-4 \
  --snr_gamma=5.0 \
  --lr_scheduler="constant" \
  --lr_warmup_steps=0 \
  --mixed_precision="fp16" \
  --use_8bit_adam \
  --max_train_steps=500 \
  --checkpointing_steps=717 \
  --seed="0"
# Out:
# 2024-05-28 21:19:27.539996: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-05-28 21:19:27.539995: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-05-28 21:19:27.576631: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-28 21:19:27.576631: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-28 21:19:28.199424: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-05-28 21:19:28.199445: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 05/28/2024 21:19:29 - INFO - __main__ - Distributed environment: MULTI_GPU  Backend: nccl
# Num processes: 2
# Process index: 0
# Local process index: 0
# Device: cuda:0
#
# Mixed precision type: fp16
#
# 05/28/2024 21:19:29 - INFO - __main__ - Distributed environment: MULTI_GPU  Backend: nccl
# Num processes: 2
# Process index: 1
# Local process index: 1
# Device: cuda:1
#
# Mixed precision type: fp16
#
# /home/emma/code/emotiscope/moody-env/lib/python3.10/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /home/emma/code/emotiscope/moody-env/lib/python3.10/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# You are using a model of type clip_text_model to instantiate a model of type . This is not supported for all configurations of models and can yield errors.
# You are using a model of type clip_text_model to instantiate a model of type . This is not supported for all configurations of models and can yield errors.
# {'dynamic_thresholding_ratio', 'clip_sample_range', 'rescale_betas_zero_snr', 'thresholding', 'variance_type'} was not found in config. Values will be initialized to default values.
# {'latents_mean', 'latents_std'} was not found in config. Values will be initialized to default values.
# {'attention_type', 'reverse_transformer_layers_per_block', 'dropout'} was not found in config. Values will be initialized to default values.
# 05/28/2024 21:19:36 - INFO - datasets - PyTorch version 2.3.0 available.
# 05/28/2024 21:19:36 - INFO - datasets - TensorFlow version 2.16.1 available.
# Resolving data files: 100%|█████████████████| 35/35 [00:00<00:00, 287844.39it/s]
# Downloading data: 100%|███████████████████| 34/34 [00:00<00:00, 48292.02files/s]
# Generating train split: 33 examples [00:00, 3681.86 examples/s]
# 05/28/2024 21:19:37 - INFO - datasets - PyTorch version 2.3.0 available.
# 05/28/2024 21:19:37 - INFO - datasets - TensorFlow version 2.16.1 available.
# Resolving data files: 100%|█████████████████| 35/35 [00:00<00:00, 290694.34it/s]
# 05/28/2024 21:19:39 - INFO - __main__ - ***** Running training *****
# 05/28/2024 21:19:39 - INFO - __main__ -   Num examples = 33
# 05/28/2024 21:19:39 - INFO - __main__ -   Num batches each epoch = 17
# 05/28/2024 21:19:39 - INFO - __main__ -   Num Epochs = 84
# 05/28/2024 21:19:39 - INFO - __main__ -   Instantaneous batch size per device = 1
# 05/28/2024 21:19:39 - INFO - __main__ -   Total train batch size (w. parallel, distributed & accumulation) = 6
# 05/28/2024 21:19:39 - INFO - __main__ -   Gradient Accumulation steps = 3
# 05/28/2024 21:19:39 - INFO - __main__ -   Total optimization steps = 500
# Steps:   0%|                                            | 0/500 [00:00<?, ?it/s]/home/emma/code/emotiscope/moody-env/lib/python3.10/site-packages/torch/nn/modules/conv.py:456: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:919.)
#   return F.conv2d(input, weight, bias, self.stride,
# /home/emma/code/emotiscope/moody-env/lib/python3.10/site-packages/torch/nn/modules/conv.py:456: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:919.)
#   return F.conv2d(input, weight, bias, self.stride,
# Steps:   0%|                     | 0/500 [00:03<?, ?it/s, loss=0.261, lr=0.0001][rank1]:[W reducer.cpp:1389] Warning: find_unused_parameters=True was specified in DDP constructor, but did not find any unused parameters in the forward pass. This flag results in an extra traversal of the autograd graph every iteration,  which can adversely affect performance. If your model indeed never has any unused parameters in the forward pass, consider turning this flag off. Note that this warning may be a false positive if your model has flow control causing later iterations to have unused parameters. (function operator())
# [rank0]:[W reducer.cpp:1389] Warning: find_unused_parameters=True was specified in DDP constructor, but did not find any unused parameters in the forward pass. This flag results in an extra traversal of the autograd graph every iteration,  which can adversely affect performance. If your model indeed never has any unused parameters in the forward pass, consider turning this flag off. Note that this warning may be a false positive if your model has flow control causing later iterations to have unused parameters. (function operator())
# Steps: 100%|███████████| 500/500 [24:56<00:00,  2.99s/it, loss=0.104, lr=0.0001]Model weights saved in claymore_LoRA/pytorch_lora_weights.safetensors
# {'latents_mean', 'latents_std'} was not found in config. Values will be initialized to default values.
# {'feature_extractor', 'image_encoder'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0%|                     | 0/7 [00:00<?, ?it/s]Loaded tokenizer_2 as CLIPTokenizer from `tokenizer_2` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
# {'attention_type', 'reverse_transformer_layers_per_block', 'dropout'} was not found in config. Values will be initialized to default values.
# Loaded unet as UNet2DConditionModel from `unet` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
#
# Loading pipeline components...:  29%|███▋         | 2/7 [00:02<00:07,  1.45s/it]Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
#
# Loading pipeline components...:  57%|███████▍     | 4/7 [00:03<00:02,  1.39it/s]{'timestep_type', 'final_sigmas_type', 'sigma_max', 'rescale_betas_zero_snr', 'sigma_min'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as EulerDiscreteScheduler from `scheduler` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
# Loaded text_encoder_2 as CLIPTextModelWithProjection from `text_encoder_2` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
#
# Loading pipeline components...:  86%|███████████▏ | 6/7 [00:04<00:00,  1.59it/s]Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
# Loading pipeline components...: 100%|█████████████| 7/7 [00:04<00:00,  1.59it/s]
# Loading unet.
# Steps: 100%|███████████| 500/500 [25:02<00:00,  3.01s/it, loss=0.104, lr=0.0001]

# %%
from huggingface_hub import whoami
from pathlib import Path
#@markdown Make sure the `output_dir` you specify here is the same as the one used for training
output_dir = f"{MODEL_NAME}_LoRA" #@param
username = whoami(token=Path("/root/.cache/huggingface/"))["name"]
repo_id = f"{username}/{output_dir}"

# %%
# @markdown Sometimes training finishes succesfuly (i.e. a **.safetensores** file with the LoRA weights saved properly to your local `output_dir`) but there's not enough RAM in the free tier to push the model to the hub 🙁
# @markdown
# @markdown To mitigate this, run this cell with your training arguments to make sure your model is uploaded! 🤗

# push to the hub🔥
from train_dreambooth_lora_sdxl import save_model_card
from huggingface_hub import upload_folder, create_repo

repo_id = create_repo(repo_id, exist_ok=True).repo_id

# change the params below according to your training arguments
save_model_card(
    repo_id = repo_id,
    images=[],
    base_model="stabilityai/stable-diffusion-xl-base-1.0",
    train_text_encoder=False,
    instance_prompt="'a TOK emoticon'",
    validation_prompt=None,
    repo_folder=output_dir,
    vae_path="madebyollin/sdxl-vae-fp16-fix",
    use_dora=False
)

upload_folder(
    repo_id=repo_id,
    folder_path=output_dir,
    commit_message="End of training",
    ignore_patterns=["step_*", "epoch_*"],
)
# Out:
# events.out.tfevents.1716956379.imagination.179069.0:   0%|          | 0.00/118k [00:00<?, ?B/s]
# events.out.tfevents.1716956379.imagination.179069.1:   0%|          | 0.00/3.29k [00:00<?, ?B/s]
# Upload 3 LFS files:   0%|          | 0/3 [00:00<?, ?it/s]
# pytorch_lora_weights.safetensors:   0%|          | 0.00/23.4M [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/nworb-ucsb/claymore_LoRA/commit/ab10e4f5c54d90b5a428577a541d5417433e9bcf', commit_message='End of training', commit_description='', oid='ab10e4f5c54d90b5a428577a541d5417433e9bcf', pr_url=None, pr_revision=None, pr_num=None)

# %%
from IPython.display import display, Markdown

link_to_model = f"https://huggingface.co/{repo_id}"
display(Markdown("### Your model has finished training.\nAccess it here: {}".format(link_to_model)))
# Out:
# ### Your model has finished training.
# Access it here: https://huggingface.co/nworb-ucsb/claymore_LoRA

# %% [markdown]
# # Inference

# %%
import torch
from diffusers import DiffusionPipeline, AutoencoderKL

vae = AutoencoderKL.from_pretrained("madebyollin/sdxl-vae-fp16-fix", torch_dtype=torch.float16)
pipe = DiffusionPipeline.from_pretrained(
    "stabilityai/stable-diffusion-xl-base-1.0",
    vae=vae,
    torch_dtype=torch.float16,
    variant="fp16",
    use_safetensors=True
)
pipe.load_lora_weights(repo_id)
_ = pipe.to("cuda")
# Out:
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# pytorch_lora_weights.safetensors:   0%|          | 0.00/23.4M [00:00<?, ?B/s]

# %%
prompt = "happy" # @param

image = pipe(prompt=prompt, num_inference_steps=25).images[0]
image
# Out:
#   0%|          | 0/25 [00:00<?, ?it/s]
